# %%
import librosa
import numpy
import scipy
import matplotlib.pyplot as plt
import soundfile as sf

# %%
audioFile ="./wav/ex1.wav"
audioLoad = audioFile

# %%
def loadFile(audioFile, sampleRate=16000):
    return librosa.load(audioFile, sr=sampleRate)

# %%
y,sr = loadFile(audioFile)

# %%
plt.plot(y)

# %%
sf.write(audioLoad, data, samplerate, format='ogg', subtype='vorbis')
